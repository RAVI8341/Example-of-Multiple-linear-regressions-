# %% [markdown]
# #program to develop a regression model on an existing dataset.

# %%
#importing diffrent libraries.

import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
#loading boston dataset from the sklearn.datasets.
boston = load_boston()

# %%
boston
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
#creating a dataframe of boston dataset.
bostondf = pd.DataFrame(boston.data, columns = boston.feature_names)

# %%
bostondf
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
target = pd.DataFrame(boston.target)

# %%
bostondf['MEDV'] = boston.target

# %%
#creating the same dataset using seed() function.
np.random.seed(2000)

# %%
#creating the training and test data set
train, test = train_test_split(bostondf, test_size = 0.3)

# %%
train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 392  11.57790   0.0  18.10   0.0  0.700  5.036  97.0  1.7700  24.0  666.0
# 144   2.77974   0.0  19.58   0.0  0.871  4.903  97.8  1.3459   5.0  403.0
# 311   0.79041   0.0   9.90   0.0  0.544  6.122  52.8  2.6403   4.0  304.0
# 266   0.78570  20.0   3.97   0.0  0.647  7.014  84.6  2.1329   5.0  264.0
# 153   2.14918   0.0  19.58   0.0  0.871  5.709  98.5  1.6232   5.0  403.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...   ...    ...
# 54    0.01360  75.0   4.00   0.0  0.410  5.888  47.6  7.3197   3.0  469.0
# 461   3.69311   0.0  18.10   0.0  0.713  6.376  88.4  2.5671  24.0  666.0
# 206   0.22969   0.0  10.59   0.0  0.489  6.326  52.5  4.3549   4.0  277.0
# 328   0.06617   0.0   3.24   0.0  0.460  5.868  25.8  5.2146   4.0  430.0
# 438  13.67810   0.0  18.10   0.0  0.740  5.935  87.9  1.8206  24.0  666.0
#
#      PTRATIO       B  LSTAT  MEDV
# 392     20.2  396.90  25.68   9.7
# ...

# %%
test
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS   RAD    TAX  \
# 262   0.52014  20.0   3.97   0.0  0.6470  8.398  91.5  2.2885   5.0  264.0
# 440  22.05110   0.0  18.10   0.0  0.7400  5.818  92.4  1.8662  24.0  666.0
# 342   0.02498   0.0   1.89   0.0  0.5180  6.540  59.7  6.2669   1.0  422.0
# 347   0.01870  85.0   4.15   0.0  0.4290  6.516  27.7  8.5353   4.0  351.0
# 222   0.62356   0.0   6.20   1.0  0.5070  6.879  77.7  3.2721   8.0  307.0
# ..        ...   ...    ...   ...     ...    ...   ...     ...   ...    ...
# 372   8.26725   0.0  18.10   1.0  0.6680  5.875  89.6  1.1296  24.0  666.0
# 204   0.02009  95.0   2.68   0.0  0.4161  8.034  31.9  5.1180   4.0  224.0
# 131   1.19294   0.0  21.89   0.0  0.6240  6.326  97.7  2.2710   4.0  437.0
# 122   0.09299   0.0  25.65   0.0  0.5810  5.961  92.9  2.0869   2.0  188.0
# 33    1.15172   0.0   8.14   0.0  0.5380  5.701  95.0  3.7872   4.0  307.0
#
#      PTRATIO       B  LSTAT  MEDV
# ...

# %%
X_train = train.drop('MEDV', axis = 1)
Y_train = train.drop('MEDV', axis = 1)
X_test = test.drop('MEDV', axis = 1)
Y_test = test['MEDV']

# %%
X_test
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS   RAD    TAX  \
# 262   0.52014  20.0   3.97   0.0  0.6470  8.398  91.5  2.2885   5.0  264.0
# 440  22.05110   0.0  18.10   0.0  0.7400  5.818  92.4  1.8662  24.0  666.0
# 342   0.02498   0.0   1.89   0.0  0.5180  6.540  59.7  6.2669   1.0  422.0
# 347   0.01870  85.0   4.15   0.0  0.4290  6.516  27.7  8.5353   4.0  351.0
# 222   0.62356   0.0   6.20   1.0  0.5070  6.879  77.7  3.2721   8.0  307.0
# ..        ...   ...    ...   ...     ...    ...   ...     ...   ...    ...
# 372   8.26725   0.0  18.10   1.0  0.6680  5.875  89.6  1.1296  24.0  666.0
# 204   0.02009  95.0   2.68   0.0  0.4161  8.034  31.9  5.1180   4.0  224.0
# 131   1.19294   0.0  21.89   0.0  0.6240  6.326  97.7  2.2710   4.0  437.0
# 122   0.09299   0.0  25.65   0.0  0.5810  5.961  92.9  2.0869   2.0  188.0
# 33    1.15172   0.0   8.14   0.0  0.5380  5.701  95.0  3.7872   4.0  307.0
#
#      PTRATIO       B  LSTAT
# 262     13.0  386.86   5.91
# ...

# %%
#creating a linear regression model
model = linear_model.LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
#train the model using the training sets
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
#determining the accuracy of the training dataset
print('Accurecy of training datasets is : \n', model.score(X_train, Y_train))
# Out:
# Accurecy of training datasets is :
#  1.0

# %%
#displaying equation coefficient
print('value of cofficients is: \n', model.coef_)
# Out:
# value of cofficients is:
#  [[ 1.00000000e+00 -5.75519543e-16  1.11301476e-17  9.05412042e-18
#    3.91803659e-15  7.11395478e-16 -2.45274154e-16 -8.50172618e-17
#   -2.39130020e-16  6.71761679e-17 -2.09710807e-17  4.12222622e-18
#   -1.26018842e-15]
#  [-3.83175034e-15  1.00000000e+00 -9.59187519e-16  4.65223019e-15
#   -4.64597887e-14 -4.29203234e-15  5.69174369e-16 -1.04730618e-16
#   -7.96421909e-16 -1.86345460e-15  1.34507205e-16 -5.86610498e-15
#   -1.19576478e-16]
#  [ 1.25355537e-16 -7.62562058e-17  1.00000000e+00  1.30880297e-15
#   -1.39665486e-14 -7.54133525e-16  8.66405302e-17 -9.48569371e-17
#    6.07211726e-16  2.29095462e-16  1.76193312e-16  8.82403666e-16
#    5.98832854e-16]
#  [-2.68223569e-16  6.97499234e-17 -3.20235761e-16  1.00000000e+00
#    7.95795834e-16  1.24345281e-18  2.59722560e-16  1.45201601e-16
#    1.42702987e-19 -3.54569887e-17 -6.21534466e-17 -1.10225843e-16
#   -5.96853122e-17]
#  [ 3.39402065e-17 -4.03549139e-17 -2.05691032e-17 -4.95188681e-16
# ...

# %%
#displaying equation intercept
print('value of intercept is : \n', model.intercept_)
# Out:
# value of intercept is :
#  [ 1.55431223e-14  2.89013258e-12 -4.15667500e-13  4.08909018e-14
#  -3.88578059e-15  2.75335310e-14 -3.32534000e-12  1.94955163e-13
#  -1.77635684e-14  3.97903932e-13 -7.10542736e-14 -5.68434189e-14
#  -3.80140364e-13]

# %%
#Predict the output from test set
predicted = model.predict(X_test)

# %%
predicted.shape
# Out:
# (152, 13)

# %%
#determining root mean squared error
from math import sqrt
rmselm = sqrt(mean_squared_error(Y_test, predicted))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-37ca12743ac3> in <module>
#       1 #determining root mean squared error
#       2 from math import sqrt
# ----> 3 rmselm = sqrt(mean_squared_error(Y_test, predicted))
#
# C:\Ananconda\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# C:\Ananconda\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     333     0.825...
#     334     """
# --> 335     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     336         y_true, y_pred, multioutput)
# ...
